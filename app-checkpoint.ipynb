# %%
import streamlit as st
import numpy as np
import joblib

# %%
# Load trained model and scaler
model = joblib.load("iris_model.pkl")
scaler = joblib.load("scaler.pkl")

# Class names
class_names = ["setosa", "versicolor", "virginica"]

# Page config
st.set_page_config(page_title="Iris Classifier", page_icon="🌸")

# Title
st.title("🌸 Iris Flower Classifier")
st.write("Predict the species of an Iris flower using a trained Machine Learning model.")

# Sidebar
st.sidebar.header("About")
st.sidebar.write("This app uses a trained model saved using joblib.")

# Input section
st.subheader("Enter Flower Measurements")

col1, col2 = st.columns(2)

with col1:
    sepal_length = st.slider("Sepal Length", 4.0, 8.0, 5.0)
    sepal_width = st.slider("Sepal Width", 2.0, 4.5, 3.0)

with col2:
    petal_length = st.slider("Petal Length", 1.0, 7.0, 4.0)
    petal_width = st.slider("Petal Width", 0.1, 2.5, 1.0)

# Prediction
if st.button("Predict"):
    input_data = np.array([[sepal_length, sepal_width, petal_length, petal_width]])

    # ✅ Apply scaling AFTER creating input
    input_data = scaler.transform(input_data)

    prediction = model.predict(input_data)
    species = class_names[prediction[0]]

    st.subheader("Prediction Result")

    if species == "setosa":
        st.success(f"The flower is **{species.upper()}** 🌼")
    elif species == "versicolor":
        st.info(f"The flower is **{species.upper()}** 🌷")
    else:
        st.warning(f"The flower is **{species.upper()}** 🌸")

    # Input summary
    st.write("### Input Summary")
    st.write(f"Sepal Length: {sepal_length}")
    st.write(f"Sepal Width: {sepal_width}")
    st.write(f"Petal Length: {petal_length}")
    st.write(f"Petal Width: {petal_width}")
# Out:
# 2026-03-31 01:53:54.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.243 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.270 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.275 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 01:53:54.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# # Extra Features

# %%
model_choice = st.selectbox(
    "Choose Model",
    ["KNN", "Logistic Regression", "Decision Tree"]
)
# Out:
# 2026-03-31 02:08:19.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:19.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if model_choice == "KNN":
    st.write("📊 Model: KNN (Accuracy ~96%)")
elif model_choice == "Logistic Regression":
    st.write("📊 Model: Logistic Regression (Accuracy ~97%)")
else:
    st.write("📊 Model: Decision Tree (Accuracy ~95%)")
# Out:
# 2026-03-31 02:08:33.685 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:33.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:33.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.subheader("Prediction Result")

st.write("This prediction is based on the selected machine learning model and input features.")
# Out:
# 2026-03-31 02:08:46.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:46.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:46.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:46.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:46.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:08:46.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
st.markdown("---")
# Out:
# 2026-03-31 02:09:02.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:09:02.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-31 02:09:02.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

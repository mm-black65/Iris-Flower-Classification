# %%
from sklearn.datasets import make_blobs
from sklearn.cluster  import KMeans
import matplotlib.pyplot as py 
x,y_true = make_blobs(n_samples = 300, centers = 4, cluster_std = 0.6)

py.scatter(x[:,0],x[:,1],s = 50)
py.show()

# %%
kmeans = KMeans(n_clusters = 4)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

py.scatter(x[:,0],x[:,1],s = 50,cmap = 'viridis',c=y_kmeans)
py.show()

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

py.scatter(x[:,0],x[:,1],s = 50,cmap = 'viridis',c=y_kmeans)
py.show()

# %%
from sklearn.datasets import make_moons
x,y_true = make_moons(200,noise=0.05)

py.scatter(x[:,0],x[:,1],s = 50)
py.show()

# %%
kmeans= KMeans(2)
kmeans.fit(x)
y_kmeans = kmeans.predict(x)

py.scatter(x[:,0],x[:,1],c = y_kmeans)
py.show()

# %%
from sklearn.cluster import SpectralClustering
model = SpectralClustering(2,affinity = 'nearest_neighbors')
labels = model.fit_predict(x)

py.scatter(x[:,0],x[:,1],s = 50,cmap = 'viridis',c=y_kmeans)
py.show()
# Out:
# C:\Users\abhin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\manifold\_spectral_embedding.py:324: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
